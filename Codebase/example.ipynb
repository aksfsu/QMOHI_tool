# %% [markdown]
# # QMOHI Usage Example
# This file demonstrates the usage of `driver.py`
# with sample input file located at `/QMOMI-input/test_input.csv`
# Complete generic pipeline
# Input - File containing university names, keywords and Google API keys
# Output - reading level and quantity metric
# Argument - Input file in form of csv sheet along with absolute path with below columns -
# 1. University_name
# 2. Keywords
# 3. API_keys (Google API keys for custom search)
# 4. Custom search engine unique id
# 5. Selenium web driver for chrome
# 6. Output directory for storing results
# 7. Ideal document name with absolute path
# Edit the paths for 5,6 & 7 to point to the necessary files in your machine

# %% [markdown]
# Create Custom Search Engine and API_Keys
# 1. Go to https://programmablesearchengine.google.com
# 2. Once on the console create a new custom search engine (CSE):
#      2.1. Clicking on the top button in the side bar
#      2.2. You can add any url in the 'sites to search' feild (you can delete it later)
# 3. Once created, you can edit the CSE and generate api keys
#      3.1. Select your CSE in the Edit Search Enigine tab in the side bar
#      3.2. API Keys can found in Setup->Basics->Programmatic Access
#      3.3. Click on 'Get Started'
# 4. To genearte key
#      4.1. Press 'Get a Key' button
#      4.2. Select your CSE after being redirected to https://developers.google.com/custom-search/v1/introduction
# 5. API keys need to added to the `/QMOMI-input/test_input.csv` under the API_keys column
#      5.1 Assign keys values by passing them in the variable (api_key_(n)) in the cell below

# %%
import pandas as pd
import os
from QMOHI_input.preprocess_scripts import override_parameters

# %%
test_data = pd.read_csv('QMOHI_input/test_input.csv')

# %%
#Add custom search engine data
api_keys = ['AIzaSyCAmAgXrFNzS_En7UpGRnolYBnpQbStRgg','AIzaSyAeW9aSUNYM5WPnkXRZh4-K9f20iwroHfY']
cse_id = '00dd60268052357eb'
output_directory = 'QMOHI_input/experiments/2021/QMOHI_input_11thOct2021/output' 
ideal_document = 'QMOHI_input/experiments/2021/QMOHI_input_11thOct2021/pap_smear_fake_document.txt'
word_vector_model = 'QMOHI_input/experiments/2021/QMOHI_input_11thOct2021/GoogleNews-vectors-negative300.bin'

# %%
test_data = override_parameters.override_input_file_parameters(test_data, api_keys, cse_id, output_directory, ideal_document, word_vector_model)

# %%
test_data.to_csv('QMOMI_input/test_input.csv', encoding='utf-8', index=False)

# %%
# Run driver code
! python3 driver.py QMOHI_input/test_input.csv
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     /Users/rachitjoshi/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# Start Overall: 16:44:35.174112
#
# ============ PHASE 1 =============
#
# ###### Reading input file ######
# - Input file given by user:  QMOHI_input/test_input.csv
# - Setting up output directory: - Collecting input university names
#                             University_name
# 0                   Ferris State University
# 1             Grand Valley State University
# 2          University of Michigan Ann Arbor
# 3                 Michigan State University
# 4                        Oakland University
# 5                    Wayne State University
# 6               Western Michigan University
# 7                  Bemidji State University
# 8        Minnesota State University Mankato
# 9             Metropolitan State University
# 10      University of Minnesota Twin Cities
# 11        University of Minnesota Crookston
# ...

# %%
! python3 driver.py QMOMI_input/test_input.csv
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     /Users/rachitjoshi/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# Start Overall: 16:16:52.337247
#
# ============ PHASE 1 =============
#
# ###### Reading input file ######
# - Input file given by user:  QMOMI_input/test_input.csv
# - Setting up output directory: - Collecting input university names
#                             University_name
# 0                   Ferris State University
# 1             Grand Valley State University
# 2          University of Michigan Ann Arbor
# 3                 Michigan State University
# 4                        Oakland University
# 5                    Wayne State University
# 6               Western Michigan University
# 7                  Bemidji State University
# 8        Minnesota State University Mankato
# 9             Metropolitan State University
# 10      University of Minnesota Twin Cities
# 11        University of Minnesota Crookston
# ...
